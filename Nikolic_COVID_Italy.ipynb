# %%
import math
import numpy as np, matplotlib.pyplot as plt, pandas as pd
from scipy.integrate import odeint
import sys
from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# # Data

# %%
data = pd.read_csv('italy.csv', index_col=0)
data = data[9:]  # инфекции появляются только на десятый день
data['Заражений'] -= (data['Выздоровлений'] + data['Смертей'])


Infected = data['Заражений']
Recovered = data['Выздоровлений']
Death = data['Смертей']

# %%
plt.figure(figsize=(7, 5))
plt.plot(Infected, label='Infected')
plt.plot(Recovered, label='Recovered')
plt.plot(Death, label='Dead')
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()

# %% [markdown]
# # Generalized SEIR model

# %%
Image(url= "https://i.imgur.com/66y03Et.png")
# Out:
# <img src="https://i.imgur.com/66y03Et.png"/>

# %% [raw]
# alpha_       0.01 - 0.15
# beta_        0.5 - 1.2
# gamma_       0.1 - 0.5
# delta_       0.1 - 0.5
# lambda_      0.0001 - 0.6
# k_           0.0001 - 0.03
#
# #initial_params = (0.07, 1.2, 0.25, 0.25, 0.5, 0.01) #(alpha_, beta_, gamma_, delta_, lambda_, k_)

# %%
# Italy's population
N=60461826

# diff equations
def diff_equation(y, t, *params):
    P, S, E, I, Q, R, D = y
    alpha_, beta_, gamma_, delta_, lambda_, k_ = params

    dP = alpha_*S
    dS = -(beta_*(I/N) + alpha_)*S
    dE = beta_*(I/N)*S - gamma_*E
    dI = gamma_*E - delta_*I
    dQ = delta_*I - (lambda_ + k_)*Q
    dR = lambda_*Q
    dD = k_*Q

    dydt = [dP, dS, dE, dI, dQ, dR, dD]
    
    return dydt


t = np.arange(data.shape[0])[:-10] # train
y0 = [0.01*(N-2), 0.99*(N-2), 2, 0, 0, 0, 0] # [P, S, E, I, Q, R, D]

# alpha, beta, gamma, delta, lambda, k
params = [np.linspace(0.01, 0.15, 10), np.linspace(1, 1.8, 20), np.linspace(0.1, 0.5, 10), 
          np.linspace(0.1, 0.5, 10), np.linspace(0.001, 0.6, 10), np.linspace(0.0001, 0.03, 5)]

#sol = odeint(diff_equation, y0, t, args=initial_params)

# %%
def RMSE(A, B):
    return np.sqrt(((A - B)**2).mean())

# %%
from sklearn.model_selection import ParameterGrid

err = []
param_grid = {'alpha': params[0], 'beta': params[1], 'gamma': params[2], 'delta': params[3],
             'lambda': params[4], 'k': params[5]}
grid = ParameterGrid(param_grid)

for i, parameters in enumerate(grid):
    
    sol = odeint(diff_equation, 
                 y0, 
                 t, 
                 args=(parameters['alpha'], parameters['beta'], parameters['gamma'], parameters['delta'],
                       parameters['lambda'], parameters['k']))

    i_err = RMSE(Infected[:-10], sol[:, 2] + sol[:, 3] + sol[:, 4])
    r_err = RMSE(Recovered[:-10], sol[:, 5])
    d_err = RMSE(Death[:-10], sol[:, 6])
    
    if i % 5000 == 0:
        print('------------------')
        print('%s steps' %i)
        print('RMSE for Dead:', d_err)
        print('RMSE for Recovered:', r_err)
        print('RMSE for Infected:', i_err)

    err.append((i_err, r_err, d_err))
# Out:
# ------------------
# 0 steps
# RMSE for Dead: 18372.51686707796
# RMSE for Recovered: 53572.00936741035
# RMSE for Infected: 3272211.294688622
# ------------------
# 5000 steps
# RMSE for Dead: 17949.802387807442
# RMSE for Recovered: 48654.56188439996
# RMSE for Infected: 4537898.710733179
# ------------------
# 10000 steps
# RMSE for Dead: 17394.896532442734
# RMSE for Recovered: 42667.183551066235
# RMSE for Infected: 5895666.5281962
# ------------------
# 15000 steps
# RMSE for Dead: 16710.72613428219
# RMSE for Recovered: 36571.036081809434
# RMSE for Infected: 7250663.943315004
# ------------------
# 20000 steps
# RMSE for Dead: 15921.092217152813
# RMSE for Recovered: 32786.71468537058
# RMSE for Infected: 8544406.885586798
# ------------------
# 25000 steps
# RMSE for Dead: 15070.709498550119
# RMSE for Recovered: 34902.5850787286
# RMSE for Infected: 9752913.18272216
# ------------------
# 30000 steps
# RMSE for Dead: 14222.4911382311
# RMSE for Recovered: 44207.86375753221
# RMSE for Infected: 10872733.215657333
# ------------------
# 35000 steps
# RMSE for Dead: 13453.461866101417
# RMSE for Recovered: 58744.94638744913
# RMSE for Infected: 11909438.080132127
# ------------------
# 40000 steps
# RMSE for Dead: 12848.768237993365
# RMSE for Recovered: 76439.82471258887
# RMSE for Infected: 12871399.99965111
# ------------------
# 45000 steps
# RMSE for Dead: 12491.581773174521
# RMSE for Recovered: 96064.52434861391
# RMSE for Infected: 13767118.038076907
# ------------------
# 50000 steps
# RMSE for Dead: 12447.967178200564
# RMSE for Recovered: 116914.6514405475
# RMSE for Infected: 14604279.918911174
# ------------------
# 55000 steps
# RMSE for Dead: 12751.29122719891
# RMSE for Recovered: 138548.6435937779
# RMSE for Infected: 15389548.081403004
# ------------------
# 60000 steps
# RMSE for Dead: 13395.567152089629
# RMSE for Recovered: 160666.24406823915
# RMSE for Infected: 16128609.4142537
# ------------------
# 65000 steps
# RMSE for Dead: 14342.802046890149
# RMSE for Recovered: 183052.14187051562
# RMSE for Infected: 16826304.18327823
# ------------------
# 70000 steps
# RMSE for Dead: 15538.75704197594
# RMSE for Recovered: 205547.04662492053
# RMSE for Infected: 17486762.08362335
# ------------------
# 75000 steps
# RMSE for Dead: 16927.409069654255
# RMSE for Recovered: 228031.07264471956
# RMSE for Infected: 18113524.13607892
# ------------------
# 80000 steps
# RMSE for Dead: 18459.230741374293
# RMSE for Recovered: 250413.23365864507
# RMSE for Infected: 18709645.10583517
# ------------------
# 85000 steps
# RMSE for Dead: 20093.93279739157
# RMSE for Recovered: 272624.2841733607
# RMSE for Infected: 19277776.331717465
# ------------------
# 90000 steps
# RMSE for Dead: 21800.141843418398
# RMSE for Recovered: 294611.64524543786
# RMSE for Infected: 19820233.907799803
# ------------------
# 95000 steps
# RMSE for Dead: 23553.933335561753
# RMSE for Recovered: 316335.6336163876
# RMSE for Infected: 20339052.753571525
# ------------------
# 100000 steps
# RMSE for Dead: 19248.904736794917
# RMSE for Recovered: 64232.72343996525
# RMSE for Infected: 61646.06835879098
# ------------------
# 105000 steps
# RMSE for Dead: 19246.558481016957
# RMSE for Recovered: 64206.306339593575
# RMSE for Infected: 60185.12231035544
# ------------------
# 110000 steps
# RMSE for Dead: 19243.50739276621
# RMSE for Recovered: 64171.83451877964
# RMSE for Infected: 58265.93972653921
# ------------------
# 115000 steps
# RMSE for Dead: 19239.54975300415
# RMSE for Recovered: 64126.97152361344
# RMSE for Infected: 55780.81159201471
# ------------------
# 120000 steps
# RMSE for Dead: 19234.42915811664
# RMSE for Recovered: 64068.73972658156
# RMSE for Infected: 52635.49502392007
# ------------------
# 125000 steps
# RMSE for Dead: 19227.820676954096
# RMSE for Recovered: 63993.35623487908
# RMSE for Infected: 48814.43926516637
# ------------------
# 130000 steps
# RMSE for Dead: 19219.313879058383
# RMSE for Recovered: 63896.031375904284
# RMSE for Infected: 44555.828390052695
# ------------------
# 135000 steps
# RMSE for Dead: 19208.392215726722
# RMSE for Recovered: 63770.72353984487
# RMSE for Infected: 40790.03333352632
# ------------------
# 140000 steps
# RMSE for Dead: 19194.408247440628
# RMSE for Recovered: 63609.844373003696
# RMSE for Infected: 39950.74425444035
# ------------------
# 145000 steps
# RMSE for Dead: 19176.554340438324
# RMSE for Recovered: 63403.90995299474
# RMSE for Infected: 46059.489277345594
# ------------------
# 150000 steps
# RMSE for Dead: 19153.82867994765
# RMSE for Recovered: 63141.13655238009
# RMSE for Infected: 62127.50408873105
# ------------------
# 155000 steps
# RMSE for Dead: 19124.996972573317
# RMSE for Recovered: 62806.9863048629
# RMSE for Infected: 88894.51104573363
# ------------------
# 160000 steps
# RMSE for Dead: 19088.551029451297
# RMSE for Recovered: 62383.678711722474
# RMSE for Infected: 126929.34286558778
# ------------------
# 165000 steps
# RMSE for Dead: 19042.666651629017
# RMSE for Recovered: 61849.700056758375
# RMSE for Infected: 177685.8775974594
# ------------------
# 170000 steps
# RMSE for Dead: 18985.16517737563
# RMSE for Recovered: 61179.36822264872
# RMSE for Infected: 243401.82034520552
# ------------------
# 175000 steps
# RMSE for Dead: 18913.485372592706
# RMSE for Recovered: 60342.541814736345
# RMSE for Infected: 326847.7258899311
# ------------------
# 180000 steps
# RMSE for Dead: 18824.67514499127
# RMSE for Recovered: 59304.60149158111
# RMSE for Infected: 431086.62021243566
# ------------------
# 185000 steps
# RMSE for Dead: 18715.415008189575
# RMSE for Recovered: 58026.86917655662
# RMSE for Infected: 559198.5913018611
# ------------------
# 190000 steps
# RMSE for Dead: 18582.08636311669
# RMSE for Recovered: 56467.65772490551
# RMSE for Infected: 713943.7877600467
# ------------------
# 195000 steps
# RMSE for Dead: 18420.89575404147
# RMSE for Recovered: 54584.142695487746
# RMSE for Infected: 897383.0279759377
# ------------------
# 200000 steps
# RMSE for Dead: 19255.478723753276
# RMSE for Recovered: 64306.15683725209
# RMSE for Infected: 65545.16619917635
# ------------------
# 205000 steps
# RMSE for Dead: 19255.299728317405
# RMSE for Recovered: 64304.27179430971
# RMSE for Infected: 65479.4389151804
# ------------------
# 210000 steps
# RMSE for Dead: 19255.0870138109
# RMSE for Recovered: 64302.02665584865
# RMSE for Infected: 65399.95770481337
# ------------------
# 215000 steps
# RMSE for Dead: 19254.83459034076
# RMSE for Recovered: 64299.35661060083
# RMSE for Infected: 65304.03359230205
# ------------------
# 220000 steps
# RMSE for Dead: 19254.53546591863
# RMSE for Recovered: 64296.1858697915
# RMSE for Infected: 65188.48688413011
# ------------------
# 225000 steps
# RMSE for Dead: 19254.18148846717
# RMSE for Recovered: 64292.425916007756
# RMSE for Infected: 65049.563803322475
# ------------------
# 230000 steps
# RMSE for Dead: 19253.76316459852
# RMSE for Recovered: 64287.973491893405
# RMSE for Infected: 64882.84031037687
# ------------------
# 235000 steps
# RMSE for Dead: 19253.26945161833
# RMSE for Recovered: 64282.70828807677
# RMSE for Infected: 64683.11110674615
# ------------------
# 240000 steps
# RMSE for Dead: 19252.687519311447
# RMSE for Recovered: 64276.49029194668
# RMSE for Infected: 64444.26229882846
# ------------------
# 245000 steps
# RMSE for Dead: 19252.00247717815
# RMSE for Recovered: 64269.15674721086
# RMSE for Infected: 64159.12542715061
# ------------------
# 250000 steps
# RMSE for Dead: 19251.19706279594
# RMSE for Recovered: 64260.51867600827
# RMSE for Infected: 63819.31137524287
# ------------------
# 255000 steps
# RMSE for Dead: 19250.25128565508
# RMSE for Recovered: 64250.35689823176
# RMSE for Infected: 63415.02180938739
# ------------------
# 260000 steps
# RMSE for Dead: 19249.14202138788
# RMSE for Recovered: 64238.41749087815
# RMSE for Infected: 62934.83741893405
# ------------------
# 265000 steps
# RMSE for Dead: 19247.842548993976
# RMSE for Recovered: 64224.406602663475
# RMSE for Infected: 62365.48164469554
# ------------------
# 270000 steps
# RMSE for Dead: 19246.3220252254
# RMSE for Recovered: 64207.98455691641
# RMSE for Infected: 61691.5614650131
# ------------------
# 275000 steps
# RMSE for Dead: 19244.54488651884
# RMSE for Recovered: 64188.75913316495
# RMSE for Infected: 60895.2878220359
# ------------------
# 280000 steps
# RMSE for Dead: 19242.470171809437
# RMSE for Recovered: 64166.27795048666
# RMSE for Infected: 59956.184517405374
# ------------------
# 285000 steps
# RMSE for Dead: 19240.05075495415
# RMSE for Recovered: 64140.01982347106
# RMSE for Infected: 58850.800545258215
# ------------------
# 290000 steps
# RMSE for Dead: 19237.23247761141
# RMSE for Recovered: 64109.384985341065
# RMSE for Infected: 57552.455689025905
# ------------------
# 295000 steps
# RMSE for Dead: 19233.95317261706
# RMSE for Recovered: 64073.68406279097
# RMSE for Infected: 56031.07378864087
# ------------------
# 300000 steps
# RMSE for Dead: 19256.08570209391
# RMSE for Recovered: 64312.54574003751
# RMSE for Infected: 65766.3685608073
# ------------------
# 305000 steps
# RMSE for Dead: 19256.043838312453
# RMSE for Recovered: 64312.11934342574
# RMSE for Infected: 65754.79821311346
# ------------------
# 310000 steps
# RMSE for Dead: 19255.996406055536
# RMSE for Recovered: 64311.63556482238
# RMSE for Infected: 65741.53348598472
# ------------------
# 315000 steps
# RMSE for Dead: 19255.942718133818
# RMSE for Recovered: 64311.08724421279
# RMSE for Infected: 65726.34612060135
# ------------------
# 320000 steps
# RMSE for Dead: 19255.88200870674
# RMSE for Recovered: 64310.46639341695
# RMSE for Infected: 65708.97953922914
# ------------------
# 325000 steps
# RMSE for Dead: 19255.81342490044
# RMSE for Recovered: 64309.76410695096
# RMSE for Infected: 65689.14559954168
# ------------------
# 330000 steps
# RMSE for Dead: 19255.736017624375
# RMSE for Recovered: 64308.97046422968
# RMSE for Infected: 65666.52100287464
# ------------------
# 335000 steps
# RMSE for Dead: 19255.64873148037
# RMSE for Recovered: 64308.074422102996
# RMSE for Infected: 65640.74334357116
# ------------------
# 340000 steps
# RMSE for Dead: 19255.55039365315
# RMSE for Recovered: 64307.063696349804
# RMSE for Infected: 65611.4067147323
# ------------------
# 345000 steps
# RMSE for Dead: 19255.439701759482
# RMSE for Recovered: 64305.9246320261
# RMSE for Infected: 65578.05688948816
# ------------------
# 350000 steps
# RMSE for Dead: 19255.315210503664
# RMSE for Recovered: 64304.642060918864
# RMSE for Infected: 65540.18598729999
# ------------------
# 355000 steps
# RMSE for Dead: 19255.17531703933
# RMSE for Recovered: 64303.199145070044
# RMSE for Infected: 65497.226601890696
# ------------------
# 360000 steps
# RMSE for Dead: 19255.018244986604
# RMSE for Recovered: 64301.57720578824
# RMSE for Infected: 65448.54534832052
# ------------------
# 365000 steps
# RMSE for Dead: 19254.842026836825
# RMSE for Recovered: 64299.75553525054
# RMSE for Infected: 65393.435727355565
# ------------------
# 370000 steps
# RMSE for Dead: 19254.64448478777
# RMSE for Recovered: 64297.71119118326
# RMSE for Infected: 65331.11032297
# ------------------
# 375000 steps
# RMSE for Dead: 19254.423209722947
# RMSE for Recovered: 64295.41877138457
# RMSE for Infected: 65260.69218415353
# ------------------
# 380000 steps
# RMSE for Dead: 19254.1755382691
# RMSE for Recovered: 64292.8501675901
# RMSE for Infected: 65181.20540875064
# ------------------
# 385000 steps
# RMSE for Dead: 19253.898527683676
# RMSE for Recovered: 64289.974295721215
# RMSE for Infected: 65091.564769259785
# ------------------
# 390000 steps
# RMSE for Dead: 19253.588928483965
# RMSE for Recovered: 64286.75680167215
# RMSE for Infected: 64990.564361714154
# ------------------
# 395000 steps
# RMSE for Dead: 19253.24315444798
# RMSE for Recovered: 64283.159738768656
# RMSE for Infected: 64876.86516919529
# ------------------
# 400000 steps
# RMSE for Dead: 19256.23229725541
# RMSE for Recovered: 64314.04376374257
# RMSE for Infected: 65807.95376800199
# ------------------
# 405000 steps
# RMSE for Dead: 19256.216082809355
# RMSE for Recovered: 64313.88155098226
# RMSE for Infected: 65804.15056931635
# ------------------
# 410000 steps
# RMSE for Dead: 19256.198231471702
# RMSE for Recovered: 64313.70280057641
# RMSE for Infected: 65799.92845803691
# ------------------
# 415000 steps
# RMSE for Dead: 19256.178592556163
# RMSE for Recovered: 64313.505975934306
# RMSE for Infected: 65795.2456955505
# ------------------
# 420000 steps
# RMSE for Dead: 19256.157002712305
# RMSE for Recovered: 64313.289410182435
# RMSE for Infected: 65790.0567720476
# ------------------
# 425000 steps
# RMSE for Dead: 19256.13328494312
# RMSE for Recovered: 64313.05129596646
# RMSE for Infected: 65784.31209287542
# ------------------
# 430000 steps
# RMSE for Dead: 19256.107247571148
# RMSE for Recovered: 64312.789674724336
# RMSE for Infected: 65777.95764897659
# ------------------
# 435000 steps
# RMSE for Dead: 19256.078683103584
# RMSE for Recovered: 64312.502424896156
# RMSE for Infected: 65770.9346524243
# ------------------
# 440000 steps
# RMSE for Dead: 19256.0473670495
# RMSE for Recovered: 64312.187249634764
# RMSE for Infected: 65763.179155212
# ------------------
# 445000 steps
# RMSE for Dead: 19256.01305663184
# RMSE for Recovered: 64311.84166341516
# RMSE for Infected: 65754.62163316565
# ------------------
# 450000 steps
# RMSE for Dead: 19255.97548941646
# RMSE for Recovered: 64311.46297777278
# RMSE for Infected: 65745.18654066352
# ------------------
# 455000 steps
# RMSE for Dead: 19255.934381849107
# RMSE for Recovered: 64311.048286083154
# RMSE for Infected: 65734.79183501043
# ------------------
# 460000 steps
# RMSE for Dead: 19255.88942770247
# RMSE for Recovered: 64310.59444737629
# RMSE for Infected: 65723.34846550619
# ------------------
# 465000 steps
# RMSE for Dead: 19255.8402963646
# RMSE for Recovered: 64310.09806853051
# RMSE for Infected: 65710.75981717293
# ------------------
# 470000 steps
# RMSE for Dead: 19255.786631095983
# RMSE for Recovered: 64309.555486085905
# RMSE for Infected: 65696.92113210041
# ------------------
# 475000 steps
# RMSE for Dead: 19255.7280470968
# RMSE for Recovered: 64308.96274610003
# RMSE for Infected: 65681.71887321731
# ------------------
# 480000 steps
# RMSE for Dead: 19255.664129482004
# RMSE for Recovered: 64308.31558301891
# RMSE for Infected: 65665.03005216768
# ------------------
# 485000 steps
# RMSE for Dead: 19255.594431079586
# RMSE for Recovered: 64307.60939670391
# RMSE for Infected: 65646.72149919841
# ------------------
# 490000 steps
# RMSE for Dead: 19255.518470149218
# RMSE for Recovered: 64306.83922860137
# RMSE for Infected: 65626.6490999563
# ------------------
# 495000 steps
# RMSE for Dead: 19255.435727866647
# RMSE for Recovered: 64305.99973546172
# RMSE for Infected: 65604.65695490353
# ------------------
# 500000 steps
# RMSE for Dead: 19256.2875374747
# RMSE for Recovered: 64314.599010303806
# RMSE for Infected: 65821.46324335525
# ------------------
# 505000 steps
# RMSE for Dead: 19256.27932264863
# RMSE for Recovered: 64314.51770094566
# RMSE for Infected: 65819.72516960798
# ------------------
# 510000 steps
# RMSE for Dead: 19256.27044871893
# RMSE for Recovered: 64314.429812034454
# RMSE for Infected: 65817.83612977939
# ------------------
# 515000 steps
# RMSE for Dead: 19256.26086828761
# RMSE for Recovered: 64314.33486663656
# RMSE for Infected: 65815.78446416918
# ------------------
# 520000 steps
# RMSE for Dead: 19256.250530892587
# RMSE for Recovered: 64314.232356754306
# RMSE for Infected: 65813.55770868302
# ------------------
# 525000 steps
# RMSE for Dead: 19256.23938282411
# RMSE for Recovered: 64314.12174145167
# RMSE for Infected: 65811.14254378987
# ------------------
# 530000 steps
# RMSE for Dead: 19256.227366937917
# RMSE for Recovered: 64314.00244494544
# RMSE for Infected: 65808.5247422394
# ------------------
# 535000 steps
# RMSE for Dead: 19256.214422455585
# RMSE for Recovered: 64313.873854565856
# RMSE for Infected: 65805.68911325849
# ------------------
# 540000 steps
# RMSE for Dead: 19256.200484753484
# RMSE for Recovered: 64313.735318599094
# RMSE for Infected: 65802.61944318334
# ------------------
# 545000 steps
# RMSE for Dead: 19256.185485146652
# RMSE for Recovered: 64313.58614407772
# RMSE for Infected: 65799.29843466627
# ------------------
# 550000 steps
# RMSE for Dead: 19256.169350649736
# RMSE for Recovered: 64313.42559433542
# RMSE for Infected: 65795.70763916743
# ------------------
# 555000 steps
# RMSE for Dead: 19256.152003737003
# RMSE for Recovered: 64313.252886552094
# RMSE for Infected: 65791.8273891108
# ------------------
# 560000 steps
# RMSE for Dead: 19256.133362081884
# RMSE for Recovered: 64313.06718908787
# RMSE for Infected: 65787.63672393284
# ------------------
# 565000 steps
# RMSE for Dead: 19256.113338295734
# RMSE for Recovered: 64312.8676188093
# RMSE for Infected: 65783.11331577005
# ------------------
# 570000 steps
# RMSE for Dead: 19256.091839630535
# RMSE for Recovered: 64312.65323804189
# RMSE for Infected: 65778.23338448019
# ------------------
# 575000 steps
# RMSE for Dead: 19256.068767680263
# RMSE for Recovered: 64312.42305151841
# RMSE for Infected: 65772.97161351042
# ------------------
# 580000 steps
# RMSE for Dead: 19256.04401807083
# RMSE for Recovered: 64312.17600319337
# RMSE for Infected: 65767.3010595583
# ------------------
# 585000 steps
# RMSE for Dead: 19256.0174801529
# RMSE for Recovered: 64311.91097309376
# RMSE for Infected: 65761.19306419669
# ------------------
# 590000 steps
# RMSE for Dead: 19255.989036610354
# RMSE for Recovered: 64311.62677331329
# RMSE for Infected: 65754.61714312984
# ------------------
# 595000 steps
# RMSE for Dead: 19255.958563119362
# RMSE for Recovered: 64311.32214450973
# RMSE for Infected: 65747.54088676727
# ------------------
# 600000 steps
# RMSE for Dead: 19256.31417734592
# RMSE for Recovered: 64314.86405177646
# RMSE for Infected: 65827.37875614094
# ------------------
# 605000 steps
# RMSE for Dead: 19256.309288463588
# RMSE for Recovered: 64314.815996162855
# RMSE for Infected: 65826.41359473155
# ------------------
# 610000 steps
# RMSE for Dead: 19256.304077834397
# RMSE for Recovered: 64314.76475391169
# RMSE for Infected: 65825.38011234456
# ------------------
# 615000 steps
# RMSE for Dead: 19256.298526794533
# RMSE for Recovered: 64314.71013888158
# RMSE for Infected: 65824.27408058045
# ------------------
# 620000 steps
# RMSE for Dead: 19256.29261572026
# RMSE for Recovered: 64314.651955295216
# RMSE for Infected: 65823.09104049912
# ------------------
# 625000 steps
# RMSE for Dead: 19256.28632398157
# RMSE for Recovered: 64314.58999727106
# RMSE for Infected: 65821.82629084775
# ------------------
# 630000 steps
# RMSE for Dead: 19256.27962989982
# RMSE for Recovered: 64314.5240483953
# RMSE for Infected: 65820.4748773142
# ------------------
# 635000 steps
# RMSE for Dead: 19256.272510695384
# RMSE for Recovered: 64314.4538811935
# RMSE for Infected: 65819.03157927874
# ------------------
# 640000 steps
# RMSE for Dead: 19256.264942440186
# RMSE for Recovered: 64314.37925665007
# RMSE for Infected: 65817.49089766365
# ------------------
# 645000 steps
# RMSE for Dead: 19256.25690000533
# RMSE for Recovered: 64314.29992367948
# RMSE for Infected: 65815.84704161526
# ------------------
# 650000 steps
# RMSE for Dead: 19256.248357006363
# RMSE for Recovered: 64314.215618572256
# RMSE for Infected: 65814.09391445397
# ------------------
# 655000 steps
# RMSE for Dead: 19256.239285747473
# RMSE for Recovered: 64314.12606443136
# RMSE for Infected: 65812.22509947667
# ------------------
# 660000 steps
# RMSE for Dead: 19256.229657162585
# RMSE for Recovered: 64314.030970575615
# RMSE for Infected: 65810.23384478285
# ------------------
# 665000 steps
# RMSE for Dead: 19256.21944075385
# RMSE for Recovered: 64313.930031917705
# RMSE for Infected: 65808.11304744925
# ------------------
# 670000 steps
# RMSE for Dead: 19256.20860452886
# RMSE for Recovered: 64313.82292832892
# RMSE for Infected: 65805.85523749187
# ------------------
# 675000 steps
# RMSE for Dead: 19256.197114934428
# RMSE for Recovered: 64313.709323968265
# RMSE for Infected: 65803.45256059698
# ------------------
# 680000 steps
# RMSE for Dead: 19256.184936787668
# RMSE for Recovered: 64313.58886658556
# RMSE for Infected: 65800.8967605386
# ------------------
# 685000 steps
# RMSE for Dead: 19256.172033203482
# RMSE for Recovered: 64313.46118678659
# RMSE for Infected: 65798.1791602671
# ------------------
# 690000 steps
# RMSE for Dead: 19256.15836552197
# RMSE for Recovered: 64313.325897297655
# RMSE for Infected: 65795.29064314794
# ------------------
# 695000 steps
# RMSE for Dead: 19256.143893231027
# RMSE for Recovered: 64313.18259218289
# RMSE for Infected: 65792.22163304806
# ------------------
# 700000 steps
# RMSE for Dead: 19256.329157686396
# RMSE for Recovered: 64315.01206908939
# RMSE for Infected: 65830.48938159623
# ------------------
# 705000 steps
# RMSE for Dead: 19256.325926353664
# RMSE for Recovered: 64314.98045817698
# RMSE for Infected: 65829.88200875805
# ------------------
# 710000 steps
# RMSE for Dead: 19256.322516542023
# RMSE for Recovered: 64314.94708930014
# RMSE for Infected: 65829.23874346275
# ------------------
# 715000 steps
# RMSE for Dead: 19256.318919700243
# RMSE for Recovered: 64314.9118777081
# RMSE for Infected: 65828.55776111825
# ------------------
# 720000 steps
# RMSE for Dead: 19256.315126917412
# RMSE for Recovered: 64314.87473506482
# RMSE for Infected: 65827.83715615139
# ------------------
# 725000 steps
# RMSE for Dead: 19256.3111289115
# RMSE for Recovered: 64314.8355693345
# RMSE for Infected: 65827.07493946186
# ------------------
# 730000 steps
# RMSE for Dead: 19256.306916013207
# RMSE for Recovered: 64314.79428461955
# RMSE for Infected: 65826.26903445445
# ------------------
# 735000 steps
# RMSE for Dead: 19256.3024781532
# RMSE for Recovered: 64314.75078103277
# RMSE for Infected: 65825.41727409956
# ------------------
# 740000 steps
# RMSE for Dead: 19256.29780484733
# RMSE for Recovered: 64314.70495454909
# RMSE for Infected: 65824.51739742397
# ------------------
# 745000 steps
# RMSE for Dead: 19256.292885180195
# RMSE for Recovered: 64314.65669684072
# RMSE for Infected: 65823.56704559302
# ------------------
# 750000 steps
# RMSE for Dead: 19256.28770779123
# RMSE for Recovered: 64314.605895137785
# RMSE for Infected: 65822.56375863332
# ------------------
# 755000 steps
# RMSE for Dead: 19256.28226085698
# RMSE for Recovered: 64314.55243205042
# RMSE for Infected: 65821.5049712096
# ------------------
# 760000 steps
# RMSE for Dead: 19256.276532074746
# RMSE for Recovered: 64314.496185404496
# RMSE for Infected: 65820.38800867442
# ------------------
# 765000 steps
# RMSE for Dead: 19256.270508646117
# RMSE for Recovered: 64314.43702807712
# RMSE for Infected: 65819.21008329692
# ------------------
# 770000 steps
# RMSE for Dead: 19256.26417725734
# RMSE for Recovered: 64314.374827798696
# RMSE for Infected: 65817.96828938102
# ------------------
# 775000 steps
# RMSE for Dead: 19256.257524063276
# RMSE for Recovered: 64314.30944699274
# RMSE for Infected: 65816.65959962324
# ------------------
# 780000 steps
# RMSE for Dead: 19256.250534664727
# RMSE for Recovered: 64314.240742547554
# RMSE for Infected: 65815.28085950675
# ------------------
# 785000 steps
# RMSE for Dead: 19256.243194094197
# RMSE for Recovered: 64314.16856567395
# RMSE for Infected: 65813.82878402082
# ------------------
# 790000 steps
# RMSE for Dead: 19256.235486790007
# RMSE for Recovered: 64314.09276164492
# RMSE for Infected: 65812.29995143593
# ------------------
# 795000 steps
# RMSE for Dead: 19256.22739657841
# RMSE for Recovered: 64314.013169616126
# RMSE for Infected: 65810.6907989263
# ------------------
# 800000 steps
# RMSE for Dead: 19256.338499298334
# RMSE for Recovered: 64315.10391905185
# RMSE for Infected: 65832.33636901912
# ------------------
# 805000 steps
# RMSE for Dead: 19256.336202557693
# RMSE for Recovered: 64315.08152888871
# RMSE for Infected: 65831.92005536561
# ------------------
# 810000 steps
# RMSE for Dead: 19256.33379748005
# RMSE for Recovered: 64315.058075950954
# RMSE for Infected: 65831.48282451121
# ------------------
# 815000 steps
# RMSE for Dead: 19256.331279698727
# RMSE for Recovered: 64315.033517161704
# RMSE for Infected: 65831.02378607582
# ------------------
# 820000 steps
# RMSE for Dead: 19256.328644694688
# RMSE for Recovered: 64315.00780793344
# RMSE for Infected: 65830.54201709517
# ------------------
# 825000 steps
# RMSE for Dead: 19256.325887791758
# RMSE for Recovered: 64314.9809021204
# RMSE for Infected: 65830.0365609439
# ------------------
# 830000 steps
# RMSE for Dead: 19256.32300415149
# RMSE for Recovered: 64314.95275196729
# RMSE for Infected: 65829.50642616645
# ------------------
# 835000 steps
# RMSE for Dead: 19256.31998876888
# RMSE for Recovered: 64314.92330806683
# RMSE for Infected: 65828.95058555447
# ------------------
# 840000 steps
# RMSE for Dead: 19256.316836466907
# RMSE for Recovered: 64314.89251930509
# RMSE for Infected: 65828.36797489012
# ------------------
# 845000 steps
# RMSE for Dead: 19256.313541891304
# RMSE for Recovered: 64314.86033280968
# RMSE for Infected: 65827.75749183222
# ------------------
# 850000 steps
# RMSE for Dead: 19256.31009950513
# RMSE for Recovered: 64314.826693895244
# RMSE for Infected: 65827.1179946057
# ------------------
# 855000 steps
# RMSE for Dead: 19256.306503584143
# RMSE for Recovered: 64314.79154601789
# RMSE for Infected: 65826.44830106999
# ------------------
# 860000 steps
# RMSE for Dead: 19256.302748209106
# RMSE for Recovered: 64314.754830697646
# RMSE for Infected: 65825.7471868599
# ------------------
# 865000 steps
# RMSE for Dead: 19256.298827262817
# RMSE for Recovered: 64314.71648748971
# RMSE for Infected: 65825.01338482343
# ------------------
# 870000 steps
# RMSE for Dead: 19256.294734421914
# RMSE for Recovered: 64314.6764539025
# RMSE for Infected: 65824.2455831995
# ------------------
# 875000 steps
# RMSE for Dead: 19256.290463151516
# RMSE for Recovered: 64314.6346653438
# RMSE for Infected: 65823.44242428409
# ------------------
# 880000 steps
# RMSE for Dead: 19256.286006699036
# RMSE for Recovered: 64314.59105505949
# RMSE for Infected: 65822.60250312708
# ------------------
# 885000 steps
# RMSE for Dead: 19256.28135808822
# RMSE for Recovered: 64314.54555407385
# RMSE for Infected: 65821.72436616557
# ------------------
# 890000 steps
# RMSE for Dead: 19256.276510111333
# RMSE for Recovered: 64314.4980911118
# RMSE for Infected: 65820.80650945744
# ------------------
# 895000 steps
# RMSE for Dead: 19256.271455323214
# RMSE for Recovered: 64314.448592539346
# RMSE for Infected: 65819.84737732861
# ------------------
# 900000 steps
# RMSE for Dead: 19256.344769705738
# RMSE for Recovered: 64315.16534625379
# RMSE for Infected: 65833.53082406378
# ------------------
# 905000 steps
# RMSE for Dead: 19256.343048884577
# RMSE for Recovered: 64315.14861450233
# RMSE for Infected: 65833.22744900454
# ------------------
# 910000 steps
# RMSE for Dead: 19256.34125778619
# RMSE for Recovered: 64315.131195465656
# RMSE for Infected: 65832.91092655626
# ------------------
# 915000 steps
# RMSE for Dead: 19256.33939399241
# RMSE for Recovered: 64315.11306537422
# RMSE for Infected: 65832.58078086941
# ------------------
# 920000 steps
# RMSE for Dead: 19256.337455013738
# RMSE for Recovered: 64315.09419975394
# RMSE for Infected: 65832.23652142199
# ------------------
# 925000 steps
# RMSE for Dead: 19256.335438287482
# RMSE for Recovered: 64315.07457340798
# RMSE for Infected: 65831.87764262721
# ------------------
# 930000 steps
# RMSE for Dead: 19256.333341175894
# RMSE for Recovered: 64315.05416039823
# RMSE for Infected: 65831.50362343188
# ------------------
# 935000 steps
# RMSE for Dead: 19256.331160964262
# RMSE for Recovered: 64315.032934026225
# RMSE for Infected: 65831.11392690876
# ------------------
# 940000 steps
# RMSE for Dead: 19256.3288948589
# RMSE for Recovered: 64315.01086681345
# RMSE for Infected: 65830.70799982476
# ------------------
# 945000 steps
# RMSE for Dead: 19256.32653998514
# RMSE for Recovered: 64314.98793048121
# RMSE for Infected: 65830.28527221044
# ------------------
# 950000 steps
# RMSE for Dead: 19256.324093385505
# RMSE for Recovered: 64314.96409593268
# RMSE for Infected: 65829.84515697506
# ------------------
# 955000 steps
# RMSE for Dead: 19256.321552017085
# RMSE for Recovered: 64314.93933322672
# RMSE for Infected: 65829.38704931726
# ------------------
# 960000 steps
# RMSE for Dead: 19256.31891275013
# RMSE for Recovered: 64314.913611564014
# RMSE for Infected: 65828.91032648162
# ------------------
# 965000 steps
# RMSE for Dead: 19256.316172365172
# RMSE for Recovered: 64314.88689925853
# RMSE for Infected: 65828.41434705725
# ------------------
# 970000 steps
# RMSE for Dead: 19256.313327551055
# RMSE for Recovered: 64314.85916371774
# RMSE for Infected: 65827.89845061036
# ------------------
# 975000 steps
# RMSE for Dead: 19256.310374902852
# RMSE for Recovered: 64314.830371422504
# RMSE for Infected: 65827.36195725946
# ------------------
# 980000 steps
# RMSE for Dead: 19256.307310919063
# RMSE for Recovered: 64314.8004878985
# RMSE for Infected: 65826.8041669863
# ------------------
# 985000 steps
# RMSE for Dead: 19256.30413199972
# RMSE for Recovered: 64314.76947769801
# RMSE for Infected: 65826.22435930034
# ------------------
# 990000 steps
# RMSE for Dead: 19256.300834443526
# RMSE for Recovered: 64314.73730437127
# RMSE for Infected: 65825.62179259732
# ------------------
# 995000 steps
# RMSE for Dead: 19256.29741444533
# RMSE for Recovered: 64314.70393044144
# RMSE for Infected: 65824.9957036077

# %%
np.save('italy_err', err)

# %%
opt_i = grid[np.argmin(err, axis=0)[0]]
opt_r = grid[np.argmin(err, axis=0)[1]]
opt_d = grid[np.argmin(err, axis=0)[2]]

# %%
ls = [(a+b+c)/3 for a, b, c in err]
opt_avg = grid[np.argmin(ls, axis=0)]

# %% [markdown]
# # Good fit: average

# %%
# now, to draw we use full dataset
t = np.arange(data.shape[0])

# %%
sol = odeint(diff_equation, 
             y0, 
             t, 
             args=(opt_avg['alpha'], opt_avg['beta'], opt_avg['gamma'], opt_avg['delta'],
                   opt_avg['lambda'], opt_avg['k']))

plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.plot(t, Infected, 'b', label='Infected')
plt.plot(t, Recovered, 'g', label='Recovered')
plt.plot(t, Death, 'r', label='Dead')
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)


plt.subplot(1,2,2)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r', label='Dead Pred')
plt.plot(t, Infected, 'b--', label='Infected')
plt.plot(t, Recovered, 'g--', label='Recovered')
plt.plot(t, Death, 'r--', label='Dead')
plt.semilogy()
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)
# Out:
# (1, 484717.7035191303)

# %%
print('RMSE for infected on last 10 days:', RMSE(Infected[-10:], sol[:, 2][-10:] + sol[:, 3][-10:] + sol[:, 4][-10:]))
print('RMSE for recovered on last 10 days:', RMSE(Recovered[-10:], sol[:, 5][-10:]))
print('RMSE for dead on last 10 days:', RMSE(Death[-10:], sol[:, 6][-10:]))
# Out:
# RMSE for infected on last 10 days: 10297.54532123022
# RMSE for recovered on last 10 days: 5817.790138216803
# RMSE for dead on last 10 days: 22540.458036991527

# %%
print('Train RMSE scores:')
err[np.argmin(ls, axis=0)]
# Out:
# Train RMSE scores:
# (12709.315679474952, 4458.634434873493, 7710.68722199553)

# %%
print('best parameters:')
{k:round(v, 4) for k, v in opt_avg.items()}
# Out:
# best parameters:
# {'lambda': 0.0676,
#  'k': 0.0225,
#  'gamma': 0.2333,
#  'delta': 0.1444,
#  'beta': 1.1263,
#  'alpha': 0.0256}

# %%
# predicting epidemic end
# I choose best parameters and big t

t = np.arange(600)

sol = odeint(diff_equation, 
             y0, 
             t = t, 
             args=(opt_avg['alpha'], opt_avg['beta'], opt_avg['gamma'], opt_avg['delta'],
                   opt_avg['lambda'], opt_avg['k']))



plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)


plt.subplot(1,2,2)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.semilogy()
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)
# Out:
# (1, 1589668.9244435157)

# %%
x = sol[:, 2] + sol[:, 3] + sol[:, 4]
for i, val in enumerate(x):
    if val <= 1:
        print('Epidemic will end in ~ %s days' %i)
        break
# Out:
# Epidemic will end in ~ 251 days

# %% [markdown]
# # Bad fits: infected, recovered and dead

# %%
sol = odeint(diff_equation, 
             y0, 
             t, 
             args=(opt_i['alpha'], opt_i['beta'], opt_i['gamma'], opt_i['delta'],
                   opt_i['lambda'], opt_i['k']))

plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.plot(t, Infected, 'b', label='Infected')
plt.plot(t, Recovered, 'g', label='Recovered')
plt.plot(t, Death, 'r', label='Dead')
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)


plt.subplot(1,2,2)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.plot(t, Infected, 'b', label='Infected')
plt.plot(t, Recovered, 'g', label='Recovered')
plt.plot(t, Death, 'r', label='Dead')
plt.semilogy()
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)
# Out:
# (1, 529820.2859705486)

# %%
print('RMSE for infected on last 10 days:', RMSE(Infected[-10:], sol[:, 2][-10:] + sol[:, 3][-10:] + sol[:, 4][-10:]))
print('RMSE for recovered on last 10 days:', RMSE(Recovered[-10:], sol[:, 5][-10:]))
print('RMSE for dead on last 10 days:', RMSE(Death[-10:], sol[:, 6][-10:]))
# Out:
# RMSE for infected on last 10 days: 5220.00051645375
# RMSE for recovered on last 10 days: 158017.544951282
# RMSE for dead on last 10 days: 113031.94498561427

# %%
sol = odeint(diff_equation, 
             y0, 
             t, 
             args=(opt_r['alpha'], opt_r['beta'], opt_r['gamma'], opt_r['delta'],
                   opt_r['lambda'], opt_r['k']))

plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.plot(t, Infected, 'b', label='Infected')
plt.plot(t, Recovered, 'g', label='Recovered')
plt.plot(t, Death, 'r', label='Dead')
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)

plt.subplot(1,2,2)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.plot(t, Infected, 'b', label='Infected')
plt.plot(t, Recovered, 'g', label='Recovered')
plt.plot(t, Death, 'r', label='Dead')
plt.semilogy()
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)
# Out:
# (1, 10744848.676146038)

# %%
print('RMSE for infected on last 10 days:', RMSE(Infected[-10:], sol[:, 2][-10:] + sol[:, 3][-10:] + sol[:, 4][-10:]))
print('RMSE for recovered on last 10 days:', RMSE(Recovered[-10:], sol[:, 5][-10:]))
print('RMSE for dead on last 10 days:', RMSE(Death[-10:], sol[:, 6][-10:]))
# Out:
# RMSE for infected on last 10 days: 2633763.5678698327
# RMSE for recovered on last 10 days: 10098.103672773908
# RMSE for dead on last 10 days: 16527.131981942784

# %%
sol = odeint(diff_equation, 
             y0, 
             t, 
             args=(opt_d['alpha'], opt_d['beta'], opt_d['gamma'], opt_d['delta'],
                   opt_d['lambda'], opt_d['k']))

plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.plot(t, Infected, 'b', label='Infected')
plt.plot(t, Recovered, 'g', label='Recovered')
plt.plot(t, Death, 'r', label='Dead')
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)


plt.subplot(1,2,2)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.plot(t, Infected, 'b', label='Infected')
plt.plot(t, Recovered, 'g', label='Recovered')
plt.plot(t, Death, 'r', label='Dead')
plt.semilogy()
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)
# Out:
# (1, 868600.7789303021)

# %%
print('RMSE for infected on last 10 days:', RMSE(Infected[-10:], sol[:, 2][-10:] + sol[:, 3][-10:] + sol[:, 4][-10:]))
print('RMSE for recovered on last 10 days:', RMSE(Recovered[-10:], sol[:, 5][-10:]))
print('RMSE for dead on last 10 days:', RMSE(Death[-10:], sol[:, 6][-10:]))
# Out:
# RMSE for infected on last 10 days: 32694.630830608636
# RMSE for recovered on last 10 days: 128278.44830636683
# RMSE for dead on last 10 days: 1085.0346329940198
