# %%
import math
import numpy as np, matplotlib.pyplot as plt, pandas as pd
from scipy.integrate import odeint
import sys
from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# # Data

# %%
data = pd.read_csv('spain.csv', index_col=0)
data = data[10:]  # инфекции появляются только на 11 день
data['Заражений'] -= (data['Выздоровлений'] + data['Смертей'])


Infected = data['Заражений']
Recovered = data['Выздоровлений']
Death = data['Смертей']

# %%
plt.figure(figsize=(7, 5))
plt.plot(Infected, label='Infected')
plt.plot(Recovered, label='Recovered')
plt.plot(Death, label='Dead')
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()

# %% [markdown]
# # Generalized SEIR model

# %%
Image(url= "https://i.imgur.com/66y03Et.png")
# Out:
# <img src="https://i.imgur.com/66y03Et.png"/>

# %%
# Spain's population
N=46754778

# diff equations
def diff_equation(y, t, *params):
    P, S, E, I, Q, R, D = y
    alpha_, beta_, gamma_, delta_, lambda_, k_ = params

    dP = alpha_*S
    dS = -(beta_*(I/N) + alpha_)*S
    dE = beta_*(I/N)*S - gamma_*E
    dI = gamma_*E - delta_*I
    dQ = delta_*I - (lambda_ + k_)*Q
    dR = lambda_*Q
    dD = k_*Q

    dydt = [dP, dS, dE, dI, dQ, dR, dD]
    
    return dydt


t = np.arange(data.shape[0])[:-10] # train
y0 = [0.01*(N-2), 0.99*(N-2), 2, 0, 0, 0, 0] # [P, S, E, I, Q, R, D]

# alpha, beta, gamma, delta, lambda, k
params = [np.linspace(0.01, 0.15, 10), np.linspace(1, 1.8, 20), np.linspace(0.1, 0.5, 10), 
          np.linspace(0.1, 0.5, 10), np.linspace(0.001, 0.6, 10), np.linspace(0.0001, 0.03, 5)]

#sol = odeint(diff_equation, y0, t, args=initial_params)

# %%
def RMSE(A, B):
    return np.sqrt(((A - B)**2).mean())

# %%
from sklearn.model_selection import ParameterGrid

err = []
param_grid = {'alpha': params[0], 'beta': params[1], 'gamma': params[2], 'delta': params[3],
             'lambda': params[4], 'k': params[5]}
grid = ParameterGrid(param_grid)

for i, parameters in enumerate(grid):
    
    sol = odeint(diff_equation, 
                 y0, 
                 t, 
                 args=(parameters['alpha'], parameters['beta'], parameters['gamma'], parameters['delta'],
                       parameters['lambda'], parameters['k']))

    i_err = RMSE(Infected[:-10], sol[:, 2] + sol[:, 3] + sol[:, 4])
    r_err = RMSE(Recovered[:-10], sol[:, 5])
    d_err = RMSE(Death[:-10], sol[:, 6])
    
    if i % 5000 == 0:
        print('------------------')
        print('%s steps' %i)
        print('RMSE for Dead:', d_err)
        print('RMSE for Recovered:', r_err)
        print('RMSE for Infected:', i_err)

    err.append((i_err, r_err, d_err))
# Out:
# ------------------
# 0 steps
# RMSE for Dead: 15720.344824112612
# RMSE for Recovered: 70829.46451819915
# RMSE for Infected: 2849162.0733279535
# ------------------
# 5000 steps
# RMSE for Dead: 15358.62088542361
# RMSE for Recovered: 67048.2469130366
# RMSE for Infected: 3872136.7145584063
# ------------------
# 10000 steps
# RMSE for Dead: 14890.64174389552
# RMSE for Recovered: 62392.37415080739
# RMSE for Infected: 4942414.109894918
# ------------------
# 15000 steps
# RMSE for Dead: 14320.885581129767
# RMSE for Recovered: 57229.59146361913
# RMSE for Infected: 5993013.8243213445
# ------------------
# 20000 steps
# RMSE for Dead: 13668.909088645
# RMSE for Recovered: 52346.588695954924
# RMSE for Infected: 6987083.871372144
# ------------------
# 25000 steps
# RMSE for Dead: 12968.237823982945
# RMSE for Recovered: 49008.62967053608
# RMSE for Infected: 7911832.725246031
# ------------------
# 30000 steps
# RMSE for Dead: 12263.700223319556
# RMSE for Recovered: 48732.884260546685
# RMSE for Infected: 8767454.25790408
# ------------------
# 35000 steps
# RMSE for Dead: 11608.37276474699
# RMSE for Recovered: 52550.04502135251
# RMSE for Infected: 9559379.925591828
# ------------------
# 40000 steps
# RMSE for Dead: 11060.028223849362
# RMSE for Recovered: 60367.144512024825
# RMSE for Infected: 10294404.65994795
# ------------------
# 45000 steps
# RMSE for Dead: 10675.916257475925
# RMSE for Recovered: 71298.22465955305
# RMSE for Infected: 10979109.337688077
# ------------------
# 50000 steps
# RMSE for Dead: 10504.925515651401
# RMSE for Recovered: 84372.242845444
# RMSE for Infected: 11619348.14159394
# ------------------
# 55000 steps
# RMSE for Dead: 10578.382984611904
# RMSE for Recovered: 98848.26670059534
# RMSE for Infected: 12220163.048788086
# ------------------
# 60000 steps
# RMSE for Dead: 10903.688717774809
# RMSE for Recovered: 114220.7202090673
# RMSE for Infected: 12785848.966038013
# ------------------
# 65000 steps
# RMSE for Dead: 11464.947269282553
# RMSE for Recovered: 130150.34617177332
# RMSE for Infected: 13320059.35179551
# ------------------
# 70000 steps
# RMSE for Dead: 12230.319143236564
# RMSE for Recovered: 146405.6831105335
# RMSE for Infected: 13825911.571748273
# ------------------
# 75000 steps
# RMSE for Dead: 13161.55712544533
# RMSE for Recovered: 162824.95393772947
# RMSE for Infected: 14306079.920407353
# ------------------
# 80000 steps
# RMSE for Dead: 14221.39768589902
# RMSE for Recovered: 179292.56038754582
# RMSE for Infected: 14762873.31088352
# ------------------
# 85000 steps
# RMSE for Dead: 15377.424973195255
# RMSE for Recovered: 195724.47169548183
# RMSE for Infected: 15198298.349262014
# ------------------
# 90000 steps
# RMSE for Dead: 16603.192743345557
# RMSE for Recovered: 212058.89183879562
# RMSE for Infected: 15614110.332153989
# ------------------
# 95000 steps
# RMSE for Dead: 17877.87570573592
# RMSE for Recovered: 228250.0958747999
# RMSE for Infected: 16011854.160159301
# ------------------
# 100000 steps
# RMSE for Dead: 16494.622620290826
# RMSE for Recovered: 79270.29861081592
# RMSE for Infected: 51549.01540773594
# ------------------
# 105000 steps
# RMSE for Dead: 16492.373247647116
# RMSE for Recovered: 79246.24502272351
# RMSE for Infected: 50104.94332935735
# ------------------
# 110000 steps
# RMSE for Dead: 16489.451832838407
# RMSE for Recovered: 79214.95563784557
# RMSE for Infected: 48213.93178221359
# ------------------
# 115000 steps
# RMSE for Dead: 16485.667261516035
# RMSE for Recovered: 79174.36061571918
# RMSE for Infected: 45779.368034380735
# ------------------
# 120000 steps
# RMSE for Dead: 16480.7770432998
# RMSE for Recovered: 79121.83105901902
# RMSE for Infected: 42732.89281498613
# ------------------
# 125000 steps
# RMSE for Dead: 16474.474487969237
# RMSE for Recovered: 79054.03909316569
# RMSE for Infected: 39123.98927497662
# ------------------
# 130000 steps
# RMSE for Dead: 16466.373076679556
# RMSE for Recovered: 78966.7874320202
# RMSE for Infected: 35361.75708770882
# ------------------
# 135000 steps
# RMSE for Dead: 16455.98762191575
# RMSE for Recovered: 78854.80416212986
# RMSE for Infected: 32789.116162794664
# ------------------
# 140000 steps
# RMSE for Dead: 16442.711864164554
# RMSE for Recovered: 78711.49922659078
# RMSE for Infected: 34390.27090182258
# ------------------
# 145000 steps
# RMSE for Dead: 16425.79234017941
# RMSE for Recovered: 78528.68137365436
# RMSE for Infected: 43655.44398732635
# ------------------
# 150000 steps
# RMSE for Dead: 16404.298658521468
# RMSE for Recovered: 78296.23804634363
# RMSE for Infected: 61971.35141993581
# ------------------
# 155000 steps
# RMSE for Dead: 16377.090932616873
# RMSE for Recovered: 78001.78803954473
# RMSE for Infected: 89545.90489418268
# ------------------
# 160000 steps
# RMSE for Dead: 16342.786034592546
# RMSE for Recovered: 77630.32771320007
# RMSE for Infected: 127165.53085161913
# ------------------
# 165000 steps
# RMSE for Dead: 16299.725630274972
# RMSE for Recovered: 77163.90716551308
# RMSE for Infected: 176388.096641989
# ------------------
# 170000 steps
# RMSE for Dead: 16245.950859554609
# RMSE for Recovered: 76581.39551927941
# RMSE for Infected: 239303.58857069156
# ------------------
# 175000 steps
# RMSE for Dead: 16179.190558037097
# RMSE for Recovered: 75858.41923620303
# RMSE for Infected: 318307.3995379448
# ------------------
# 180000 steps
# RMSE for Dead: 16096.872088044429
# RMSE for Recovered: 74967.58407384869
# RMSE for Infected: 415871.06577412435
# ------------------
# 185000 steps
# RMSE for Dead: 15996.164958482612
# RMSE for Recovered: 73879.10666499926
# RMSE for Infected: 534273.012173546
# ------------------
# 190000 steps
# RMSE for Dead: 15874.06665783822
# RMSE for Recovered: 72561.97663339133
# RMSE for Infected: 675291.7193036375
# ------------------
# 195000 steps
# RMSE for Dead: 15727.535875350386
# RMSE for Recovered: 70985.72715473126
# RMSE for Infected: 839904.1893037291
# ------------------
# 200000 steps
# RMSE for Dead: 16500.943739205475
# RMSE for Recovered: 79337.65326487075
# RMSE for Infected: 55415.94697268565
# ------------------
# 205000 steps
# RMSE for Dead: 16500.769097413384
# RMSE for Recovered: 79335.84403662368
# RMSE for Infected: 55350.78631540942
# ------------------
# 210000 steps
# RMSE for Dead: 16500.561628488624
# RMSE for Recovered: 79333.69231771697
# RMSE for Infected: 55271.971802468404
# ------------------
# 215000 steps
# RMSE for Dead: 16500.31551562888
# RMSE for Recovered: 79331.1370222376
# RMSE for Infected: 55176.83241026405
# ------------------
# 220000 steps
# RMSE for Dead: 16500.02397168806
# RMSE for Recovered: 79328.10681207872
# RMSE for Infected: 55062.20993248867
# ------------------
# 225000 steps
# RMSE for Dead: 16499.679086709428
# RMSE for Recovered: 79324.51847695201
# RMSE for Infected: 54924.37644367362
# ------------------
# 230000 steps
# RMSE for Dead: 16499.271653142005
# RMSE for Recovered: 79320.27507612192
# RMSE for Infected: 54758.93919185319
# ------------------
# 235000 steps
# RMSE for Dead: 16498.790965365595
# RMSE for Recovered: 79315.26380547036
# RMSE for Infected: 54560.73101027163
# ------------------
# 240000 steps
# RMSE for Dead: 16498.224590232043
# RMSE for Recovered: 79309.35355484062
# RMSE for Infected: 54323.68484902214
# ------------------
# 245000 steps
# RMSE for Dead: 16497.558104530955
# RMSE for Recovered: 79302.39211135749
# RMSE for Infected: 54040.69033038597
# ------------------
# 250000 steps
# RMSE for Dead: 16496.774795260913
# RMSE for Recovered: 79294.2029648684
# RMSE for Infected: 53703.43111173482
# ------------------
# 255000 steps
# RMSE for Dead: 16495.855317392627
# RMSE for Recovered: 79284.58165801475
# RMSE for Infected: 53302.201146457286
# ------------------
# 260000 steps
# RMSE for Dead: 16494.777304335592
# RMSE for Recovered: 79273.29162976274
# RMSE for Infected: 52825.69975034649
# ------------------
# 265000 steps
# RMSE for Dead: 16493.514924173105
# RMSE for Recovered: 79260.05947772242
# RMSE for Infected: 52260.80519482226
# ------------------
# 270000 steps
# RMSE for Dead: 16492.038376275133
# RMSE for Recovered: 79244.56958124018
# RMSE for Infected: 51592.33002439875
# ------------------
# 275000 steps
# RMSE for Dead: 16490.313319331814
# RMSE for Recovered: 79226.45798911646
# RMSE for Infected: 50802.763373253605
# ------------------
# 280000 steps
# RMSE for Dead: 16488.300224789335
# RMSE for Recovered: 79205.30550714108
# RMSE for Infected: 49872.0136105955
# ------------------
# 285000 steps
# RMSE for Dead: 16485.953645379013
# RMSE for Recovered: 79180.6298748166
# RMSE for Infected: 48777.17415273434
# ------------------
# 290000 steps
# RMSE for Dead: 16483.221390606144
# RMSE for Recovered: 79151.87694389236
# RMSE for Infected: 47492.35631773914
# ------------------
# 295000 steps
# RMSE for Dead: 16480.043600563728
# RMSE for Recovered: 79118.41076613188
# RMSE for Infected: 45988.66986622319
# ------------------
# 300000 steps
# RMSE for Dead: 16501.53612988324
# RMSE for Recovered: 79343.78914432033
# RMSE for Infected: 55635.24982802253
# ------------------
# 305000 steps
# RMSE for Dead: 16501.495105331847
# RMSE for Recovered: 79343.3712697647
# RMSE for Infected: 55623.84489189252
# ------------------
# 310000 steps
# RMSE for Dead: 16501.448628878625
# RMSE for Recovered: 79342.89752278365
# RMSE for Infected: 55610.76624979091
# ------------------
# 315000 steps
# RMSE for Dead: 16501.396028490097
# RMSE for Recovered: 79342.360976609
# RMSE for Infected: 55595.78797862771
# ------------------
# 320000 steps
# RMSE for Dead: 16501.336555321766
# RMSE for Recovered: 79341.75390846457
# RMSE for Infected: 55578.656081079775
# ------------------
# 325000 steps
# RMSE for Dead: 16501.26937554529
# RMSE for Recovered: 79341.06771444077
# RMSE for Infected: 55559.08526528833
# ------------------
# 330000 steps
# RMSE for Dead: 16501.193561396554
# RMSE for Recovered: 79340.29281618747
# RMSE for Infected: 55536.75538113389
# ------------------
# 335000 steps
# RMSE for Dead: 16501.108081340008
# RMSE for Recovered: 79339.4185583975
# RMSE for Infected: 55511.307501356656
# ------------------
# 340000 steps
# RMSE for Dead: 16501.011789243144
# RMSE for Recovered: 79338.43309587614
# RMSE for Infected: 55482.3395624855
# ------------------
# 345000 steps
# RMSE for Dead: 16500.90341253784
# RMSE for Recovered: 79337.32327002645
# RMSE for Infected: 55449.40158602593
# ------------------
# 350000 steps
# RMSE for Dead: 16500.78153922196
# RMSE for Recovered: 79336.07447315964
# RMSE for Infected: 55411.99038971306
# ------------------
# 355000 steps
# RMSE for Dead: 16500.644603603385
# RMSE for Recovered: 79334.67049962335
# RMSE for Infected: 55369.54376639711
# ------------------
# 360000 steps
# RMSE for Dead: 16500.4908707382
# RMSE for Recovered: 79333.09338323018
# RMSE for Infected: 55321.43408906809
# ------------------
# 365000 steps
# RMSE for Dead: 16500.318419302945
# RMSE for Recovered: 79331.32321825034
# RMSE for Infected: 55266.96124163129
# ------------------
# 370000 steps
# RMSE for Dead: 16500.125122942856
# RMSE for Recovered: 79329.33796442291
# RMSE for Infected: 55205.34489259477
# ------------------
# 375000 steps
# RMSE for Dead: 16499.908629820882
# RMSE for Recovered: 79327.11323302709
# RMSE for Infected: 55135.71596456947
# ------------------
# 380000 steps
# RMSE for Dead: 16499.66634030067
# RMSE for Recovered: 79324.62205341704
# RMSE for Infected: 55057.10732004061
# ------------------
# 385000 steps
# RMSE for Dead: 16499.39538252794
# RMSE for Recovered: 79321.83461741052
# RMSE for Infected: 54968.44350563978
# ------------------
# 390000 steps
# RMSE for Dead: 16499.09258582422
# RMSE for Recovered: 79318.71800068572
# RMSE for Infected: 54868.52953959628
# ------------------
# 395000 steps
# RMSE for Dead: 16498.754451532386
# RMSE for Recovered: 79315.2358574626
# RMSE for Infected: 54756.03863915753
# ------------------
# 400000 steps
# RMSE for Dead: 16501.679767732945
# RMSE for Recovered: 79345.25479354816
# RMSE for Infected: 55676.258901796675
# ------------------
# 405000 steps
# RMSE for Dead: 16501.66385839717
# RMSE for Recovered: 79345.09424733995
# RMSE for Infected: 55672.525426451255
# ------------------
# 410000 steps
# RMSE for Dead: 16501.646343540902
# RMSE for Recovered: 79344.91741475982
# RMSE for Infected: 55668.3800749037
# ------------------
# 415000 steps
# RMSE for Dead: 16501.627075443597
# RMSE for Recovered: 79344.72278998073
# RMSE for Infected: 55663.78173923813
# ------------------
# 420000 steps
# RMSE for Dead: 16501.605893978332
# RMSE for Recovered: 79344.50874012178
# RMSE for Infected: 55658.68559107012
# ------------------
# 425000 steps
# RMSE for Dead: 16501.58262565019
# RMSE for Recovered: 79344.27349535366
# RMSE for Infected: 55653.042771688444
# ------------------
# 430000 steps
# RMSE for Dead: 16501.557082584408
# RMSE for Recovered: 79344.01513849024
# RMSE for Infected: 55646.800066485084
# ------------------
# 435000 steps
# RMSE for Dead: 16501.529061415593
# RMSE for Recovered: 79343.73159355482
# RMSE for Infected: 55639.89954489025
# ------------------
# 440000 steps
# RMSE for Dead: 16501.49834213037
# RMSE for Recovered: 79343.42061386576
# RMSE for Infected: 55632.2781837781
# ------------------
# 445000 steps
# RMSE for Dead: 16501.464686806965
# RMSE for Recovered: 79343.07976905776
# RMSE for Infected: 55623.86745638483
# ------------------
# 450000 steps
# RMSE for Dead: 16501.42783827381
# RMSE for Recovered: 79342.7064312645
# RMSE for Infected: 55614.5928924356
# ------------------
# 455000 steps
# RMSE for Dead: 16501.387518678144
# RMSE for Recovered: 79342.29776037388
# RMSE for Infected: 55604.3736083317
# ------------------
# 460000 steps
# RMSE for Dead: 16501.343427966876
# RMSE for Recovered: 79341.85068836436
# RMSE for Infected: 55593.121802356
# ------------------
# 465000 steps
# RMSE for Dead: 16501.29524221207
# RMSE for Recovered: 79341.36190205625
# RMSE for Infected: 55580.74220538008
# ------------------
# 470000 steps
# RMSE for Dead: 16501.242611906368
# RMSE for Recovered: 79340.82782552537
# RMSE for Infected: 55567.13150925739
# ------------------
# 475000 steps
# RMSE for Dead: 16501.18516007256
# RMSE for Recovered: 79340.24460061132
# RMSE for Infected: 55552.17773859627
# ------------------
# 480000 steps
# RMSE for Dead: 16501.122480283368
# RMSE for Recovered: 79339.60806648778
# RMSE for Infected: 55535.75958710793
# ------------------
# 485000 steps
# RMSE for Dead: 16501.054134508337
# RMSE for Recovered: 79338.91373744953
# RMSE for Infected: 55517.745696868755
# ------------------
# 490000 steps
# RMSE for Dead: 16500.97965088332
# RMSE for Recovered: 79338.15677988803
# RMSE for Infected: 55497.99390501126
# ------------------
# 495000 steps
# RMSE for Dead: 16500.898521251005
# RMSE for Recovered: 79337.33198690075
# RMSE for Infected: 55476.35041417743
# ------------------
# 500000 steps
# RMSE for Dead: 16501.73396248707
# RMSE for Recovered: 79345.80306222253
# RMSE for Infected: 55689.52910947227
# ------------------
# 505000 steps
# RMSE for Dead: 16501.72589922337
# RMSE for Recovered: 79345.72214978925
# RMSE for Infected: 55687.82642044914
# ------------------
# 510000 steps
# RMSE for Dead: 16501.717189080042
# RMSE for Recovered: 79345.6347166271
# RMSE for Infected: 55685.97569776995
# ------------------
# 515000 steps
# RMSE for Dead: 16501.707785548675
# RMSE for Recovered: 79345.54029193327
# RMSE for Infected: 55683.96549520429
# ------------------
# 520000 steps
# RMSE for Dead: 16501.697639115308
# RMSE for Recovered: 79345.43837435872
# RMSE for Infected: 55681.783575895344
# ------------------
# 525000 steps
# RMSE for Dead: 16501.686697080444
# RMSE for Recovered: 79345.32843017198
# RMSE for Infected: 55679.41686214181
# ------------------
# 530000 steps
# RMSE for Dead: 16501.674903375846
# RMSE for Recovered: 79345.20989138976
# RMSE for Infected: 55676.851383952
# ------------------
# 535000 steps
# RMSE for Dead: 16501.662198368827
# RMSE for Recovered: 79345.08215377989
# RMSE for Infected: 55674.07222413928
# ------------------
# 540000 steps
# RMSE for Dead: 16501.648518655336
# RMSE for Recovered: 79344.94457474911
# RMSE for Infected: 55671.06345990532
# ------------------
# 545000 steps
# RMSE for Dead: 16501.6337968481
# RMSE for Recovered: 79344.79647118037
# RMSE for Infected: 55667.80810301899
# ------------------
# 550000 steps
# RMSE for Dead: 16501.61796134224
# RMSE for Recovered: 79344.63711703962
# RMSE for Infected: 55664.28803339764
# ------------------
# 555000 steps
# RMSE for Dead: 16501.600936080064
# RMSE for Recovered: 79344.46574097377
# RMSE for Infected: 55660.48393235157
# ------------------
# 560000 steps
# RMSE for Dead: 16501.58264029574
# RMSE for Recovered: 79344.28152370264
# RMSE for Infected: 55656.37520982072
# ------------------
# 565000 steps
# RMSE for Dead: 16501.562988259262
# RMSE for Recovered: 79344.08359540373
# RMSE for Infected: 55651.9399312577
# ------------------
# 570000 steps
# RMSE for Dead: 16501.541888984986
# RMSE for Recovered: 79343.87103273279
# RMSE for Infected: 55647.15473402465
# ------------------
# 575000 steps
# RMSE for Dead: 16501.51924593899
# RMSE for Recovered: 79343.64285583691
# RMSE for Infected: 55641.99474463505
# ------------------
# 580000 steps
# RMSE for Dead: 16501.494956735172
# RMSE for Recovered: 79343.39802524433
# RMSE for Infected: 55636.43348986784
# ------------------
# 585000 steps
# RMSE for Dead: 16501.468912834236
# RMSE for Recovered: 79343.13543878692
# RMSE for Infected: 55630.44280982875
# ------------------
# 590000 steps
# RMSE for Dead: 16501.44099915993
# RMSE for Recovered: 79342.8539276811
# RMSE for Infected: 55623.992749045494
# ------------------
# 595000 steps
# RMSE for Dead: 16501.411093764957
# RMSE for Recovered: 79342.55225310862
# RMSE for Infected: 55617.051458673486
# ------------------
# 600000 steps
# RMSE for Dead: 16501.760109933955
# RMSE for Recovered: 79346.06616514425
# RMSE for Infected: 55695.327335158225
# ------------------
# 605000 steps
# RMSE for Dead: 16501.755310807133
# RMSE for Recovered: 79346.0181836096
# RMSE for Infected: 55694.38273845979
# ------------------
# 610000 steps
# RMSE for Dead: 16501.750195831326
# RMSE for Recovered: 79345.96703147543
# RMSE for Infected: 55693.371239688706
# ------------------
# 615000 steps
# RMSE for Dead: 16501.744746686138
# RMSE for Recovered: 79345.91252415207
# RMSE for Infected: 55692.288695402036
# ------------------
# 620000 steps
# RMSE for Dead: 16501.738944109067
# RMSE for Recovered: 79345.85446752455
# RMSE for Infected: 55691.13073607753
# ------------------
# 625000 steps
# RMSE for Dead: 16501.732767850026
# RMSE for Recovered: 79345.7926574915
# RMSE for Infected: 55689.89275455948
# ------------------
# 630000 steps
# RMSE for Dead: 16501.726196629763
# RMSE for Recovered: 79345.72687954312
# RMSE for Infected: 55688.569895517205
# ------------------
# 635000 steps
# RMSE for Dead: 16501.71920808852
# RMSE for Recovered: 79345.65690824065
# RMSE for Infected: 55687.15704244103
# ------------------
# 640000 steps
# RMSE for Dead: 16501.71177873944
# RMSE for Recovered: 79345.58250674316
# RMSE for Infected: 55685.64880572191
# ------------------
# 645000 steps
# RMSE for Dead: 16501.703883917202
# RMSE for Recovered: 79345.50342628655
# RMSE for Infected: 55684.03950958208
# ------------------
# 650000 steps
# RMSE for Dead: 16501.695497724282
# RMSE for Recovered: 79345.41940563811
# RMSE for Infected: 55682.32317828737
# ------------------
# 655000 steps
# RMSE for Dead: 16501.68659297627
# RMSE for Recovered: 79345.33017054133
# RMSE for Infected: 55680.49352221862
# ------------------
# 660000 steps
# RMSE for Dead: 16501.67714114401
# RMSE for Recovered: 79345.23543312862
# RMSE for Infected: 55678.54392298042
# ------------------
# 665000 steps
# RMSE for Dead: 16501.667112293297
# RMSE for Recovered: 79345.13489130905
# RMSE for Infected: 55676.46741787318
# ------------------
# 670000 steps
# RMSE for Dead: 16501.65647502325
# RMSE for Recovered: 79345.02822814262
# RMSE for Infected: 55674.25668415997
# ------------------
# 675000 steps
# RMSE for Dead: 16501.64519640138
# RMSE for Recovered: 79344.91511118058
# RMSE for Infected: 55671.90402211915
# ------------------
# 680000 steps
# RMSE for Dead: 16501.633241895943
# RMSE for Recovered: 79344.79519177889
# RMSE for Infected: 55669.4013377984
# ------------------
# 685000 steps
# RMSE for Dead: 16501.62057530484
# RMSE for Recovered: 79344.66810437554
# RMSE for Infected: 55666.74012445809
# ------------------
# 690000 steps
# RMSE for Dead: 16501.607158684365
# RMSE for Recovered: 79344.53346576687
# RMSE for Infected: 55663.911444168785
# ------------------
# 695000 steps
# RMSE for Dead: 16501.592952273317
# RMSE for Recovered: 79344.39087433708
# RMSE for Infected: 55660.9059082773
# ------------------
# 700000 steps
# RMSE for Dead: 16501.774815648492
# RMSE for Recovered: 79346.2135999738
# RMSE for Infected: 55698.372877263224
# ------------------
# 705000 steps
# RMSE for Dead: 16501.77164365397
# RMSE for Recovered: 79346.18196696539
# RMSE for Infected: 55697.77871748437
# ------------------
# 710000 steps
# RMSE for Dead: 16501.76829644132
# RMSE for Recovered: 79346.14858019844
# RMSE for Infected: 55697.14943498654
# ------------------
# 715000 steps
# RMSE for Dead: 16501.764765615422
# RMSE for Recovered: 79346.11335536801
# RMSE for Infected: 55696.48324358473
# ------------------
# 720000 steps
# RMSE for Dead: 16501.761042428083
# RMSE for Recovered: 79346.07620461253
# RMSE for Infected: 55695.77827778114
# ------------------
# 725000 steps
# RMSE for Dead: 16501.75711776676
# RMSE for Recovered: 79346.03703640029
# RMSE for Infected: 55695.03259027437
# ------------------
# 730000 steps
# RMSE for Dead: 16501.75298213875
# RMSE for Recovered: 79345.9957553694
# RMSE for Infected: 55694.244148068654
# ------------------
# 735000 steps
# RMSE for Dead: 16501.748625658656
# RMSE for Recovered: 79345.9522622012
# RMSE for Infected: 55693.41082959598
# ------------------
# 740000 steps
# RMSE for Dead: 16501.74403803385
# RMSE for Recovered: 79345.90645347361
# RMSE for Infected: 55692.53042127791
# ------------------
# 745000 steps
# RMSE for Dead: 16501.739208548363
# RMSE for Recovered: 79345.85822149809
# RMSE for Infected: 55691.60061368745
# ------------------
# 750000 steps
# RMSE for Dead: 16501.734126049232
# RMSE for Recovered: 79345.80745418176
# RMSE for Infected: 55690.61899833851
# ------------------
# 755000 steps
# RMSE for Dead: 16501.728778929093
# RMSE for Recovered: 79345.75403485149
# RMSE for Infected: 55689.58306354942
# ------------------
# 760000 steps
# RMSE for Dead: 16501.723155110125
# RMSE for Recovered: 79345.69784209158
# RMSE for Infected: 55688.49019057065
# ------------------
# 765000 steps
# RMSE for Dead: 16501.717242027902
# RMSE for Recovered: 79345.6387495807
# RMSE for Infected: 55687.3376498962
# ------------------
# 770000 steps
# RMSE for Dead: 16501.711026612113
# RMSE for Recovered: 79345.57662589665
# RMSE for Infected: 55686.12259647495
# ------------------
# 775000 steps
# RMSE for Dead: 16501.704495270813
# RMSE for Recovered: 79345.5113343576
# RMSE for Infected: 55684.84206614915
# ------------------
# 780000 steps
# RMSE for Dead: 16501.69763386818
# RMSE for Recovered: 79345.44273279673
# RMSE for Infected: 55683.49297015752
# ------------------
# 785000 steps
# RMSE for Dead: 16501.69042771055
# RMSE for Recovered: 79345.37067342132
# RMSE for Infected: 55682.0720919284
# ------------------
# 790000 steps
# RMSE for Dead: 16501.68286152096
# RMSE for Recovered: 79345.2950025554
# RMSE for Infected: 55680.576080978855
# ------------------
# 795000 steps
# RMSE for Dead: 16501.674919421675
# RMSE for Recovered: 79345.21556046269
# RMSE for Infected: 55679.00144862639
# ------------------
# 800000 steps
# RMSE for Dead: 16501.783986361523
# RMSE for Recovered: 79346.30530321984
# RMSE for Infected: 55700.18016636984
# ------------------
# 805000 steps
# RMSE for Dead: 16501.781731880874
# RMSE for Recovered: 79346.28286172179
# RMSE for Infected: 55699.77300016336
# ------------------
# 810000 steps
# RMSE for Dead: 16501.779371042685
# RMSE for Recovered: 79346.25935798076
# RMSE for Infected: 55699.34537261414
# ------------------
# 815000 steps
# RMSE for Dead: 16501.77689955981
# RMSE for Recovered: 79346.23474905099
# RMSE for Infected: 55698.89641254311
# ------------------
# 820000 steps
# RMSE for Dead: 16501.7743129955
# RMSE for Recovered: 79346.20899048419
# RMSE for Infected: 55698.4252168823
# ------------------
# 825000 steps
# RMSE for Dead: 16501.771606758757
# RMSE for Recovered: 79346.18203628233
# RMSE for Infected: 55697.930849620774
# ------------------
# 830000 steps
# RMSE for Dead: 16501.76877609923
# RMSE for Recovered: 79346.15383884682
# RMSE for Infected: 55697.41234065991
# ------------------
# 835000 steps
# RMSE for Dead: 16501.76581610308
# RMSE for Recovered: 79346.12434893625
# RMSE for Infected: 55696.86868491101
# ------------------
# 840000 steps
# RMSE for Dead: 16501.762721687563
# RMSE for Recovered: 79346.0935156123
# RMSE for Infected: 55696.298841064905
# ------------------
# 845000 steps
# RMSE for Dead: 16501.759487595922
# RMSE for Recovered: 79346.06128618817
# RMSE for Infected: 55695.70173050256
# ------------------
# 850000 steps
# RMSE for Dead: 16501.756108392052
# RMSE for Recovered: 79346.02760617466
# RMSE for Infected: 55695.076236011264
# ------------------
# 855000 steps
# RMSE for Dead: 16501.75257845597
# RMSE for Recovered: 79345.99241923484
# RMSE for Infected: 55694.42120087425
# ------------------
# 860000 steps
# RMSE for Dead: 16501.74889197623
# RMSE for Recovered: 79345.9556671073
# RMSE for Infected: 55693.73542704968
# ------------------
# 865000 steps
# RMSE for Dead: 16501.745042947055
# RMSE for Recovered: 79345.91728957748
# RMSE for Infected: 55693.01767462163
# ------------------
# 870000 steps
# RMSE for Dead: 16501.741025160245
# RMSE for Recovered: 79345.87722439626
# RMSE for Infected: 55692.266660017594
# ------------------
# 875000 steps
# RMSE for Dead: 16501.736832199946
# RMSE for Recovered: 79345.83540722688
# RMSE for Infected: 55691.48105470103
# ------------------
# 880000 steps
# RMSE for Dead: 16501.732457436567
# RMSE for Recovered: 79345.79177158397
# RMSE for Infected: 55690.65948389768
# ------------------
# 885000 steps
# RMSE for Dead: 16501.72789402092
# RMSE for Recovered: 79345.74624877432
# RMSE for Infected: 55689.800525257815
# ------------------
# 890000 steps
# RMSE for Dead: 16501.723134876567
# RMSE for Recovered: 79345.6987678199
# RMSE for Infected: 55688.90270712794
# ------------------
# 895000 steps
# RMSE for Dead: 16501.718172693963
# RMSE for Recovered: 79345.64925539866
# RMSE for Infected: 55687.964507227036
# ------------------
# 900000 steps
# RMSE for Dead: 16501.79014199926
# RMSE for Recovered: 79346.36673714836
# RMSE for Infected: 55701.348584294275
# ------------------
# 905000 steps
# RMSE for Dead: 16501.788452919805
# RMSE for Recovered: 79346.3499472065
# RMSE for Infected: 55701.051908713125
# ------------------
# 910000 steps
# RMSE for Dead: 16501.786694849066
# RMSE for Recovered: 79346.33246934836
# RMSE for Infected: 55700.742374687834
# ------------------
# 915000 steps
# RMSE for Dead: 16501.784865412923
# RMSE for Recovered: 79346.31427983698
# RMSE for Infected: 55700.41951676519
# ------------------
# 920000 steps
# RMSE for Dead: 16501.782962167203
# RMSE for Recovered: 79346.29535423325
# RMSE for Infected: 55700.08285513849
# ------------------
# 925000 steps
# RMSE for Dead: 16501.78098259589
# RMSE for Recovered: 79346.27566737795
# RMSE for Infected: 55699.73189526369
# ------------------
# 930000 steps
# RMSE for Dead: 16501.778924109258
# RMSE for Recovered: 79346.25519337309
# RMSE for Infected: 55699.36612746667
# ------------------
# 935000 steps
# RMSE for Dead: 16501.776784042027
# RMSE for Recovered: 79346.23390556316
# RMSE for Infected: 55698.98502654429
# ------------------
# 940000 steps
# RMSE for Dead: 16501.774559651378
# RMSE for Recovered: 79346.21177651543
# RMSE for Infected: 55698.58805134222
# ------------------
# 945000 steps
# RMSE for Dead: 16501.772248114976
# RMSE for Recovered: 79346.18877799997
# RMSE for Infected: 55698.17464433363
# ------------------
# 950000 steps
# RMSE for Dead: 16501.769846529183
# RMSE for Recovered: 79346.16488097167
# RMSE for Infected: 55697.744231242905
# ------------------
# 955000 steps
# RMSE for Dead: 16501.767351906496
# RMSE for Recovered: 79346.14005554454
# RMSE for Infected: 55697.2962204688
# ------------------
# 960000 steps
# RMSE for Dead: 16501.764761174123
# RMSE for Recovered: 79346.11427097744
# RMSE for Infected: 55696.83000284705
# ------------------
# 965000 steps
# RMSE for Dead: 16501.762071171208
# RMSE for Recovered: 79346.08749564618
# RMSE for Infected: 55696.344950963445
# ------------------
# 970000 steps
# RMSE for Dead: 16501.75927864686
# RMSE for Recovered: 79346.05969702353
# RMSE for Infected: 55695.840418795
# ------------------
# 975000 steps
# RMSE for Dead: 16501.756380258135
# RMSE for Recovered: 79346.03084165936
# RMSE for Infected: 55695.31574129474
# ------------------
# 980000 steps
# RMSE for Dead: 16501.753372567255
# RMSE for Recovered: 79346.00089515219
# RMSE for Infected: 55694.77023371699
# ------------------
# 985000 steps
# RMSE for Dead: 16501.750252039776
# RMSE for Recovered: 79345.96982213113
# RMSE for Infected: 55694.20319128988
# ------------------
# 990000 steps
# RMSE for Dead: 16501.74701504176
# RMSE for Recovered: 79345.93758622734
# RMSE for Infected: 55693.61388858784
# ------------------
# 995000 steps
# RMSE for Dead: 16501.74365783731
# RMSE for Recovered: 79345.90415004922
# RMSE for Infected: 55693.00157899212

# %%
np.save('spain_err', err)

# %%
opt_i = grid[np.argmin(err, axis=0)[0]]
opt_r = grid[np.argmin(err, axis=0)[1]]
opt_d = grid[np.argmin(err, axis=0)[2]]

# %%
ls = [(a+b+c)/3 for a, b, c in err]
opt_avg = grid[np.argmin(ls, axis=0)]

# %% [markdown]
# # Good fit: average

# %%
# now, to draw we use full dataset
t = np.arange(data.shape[0])

# %%
sol = odeint(diff_equation, 
             y0, 
             t, 
             args=(opt_avg['alpha'], opt_avg['beta'], opt_avg['gamma'], opt_avg['delta'],
                   opt_avg['lambda'], opt_avg['k']))

plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.plot(t, Infected, 'b', label='Infected')
plt.plot(t, Recovered, 'g', label='Recovered')
plt.plot(t, Death, 'r', label='Dead')
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)


plt.subplot(1,2,2)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r', label='Dead Pred')
plt.plot(t, Infected, 'b--', label='Infected')
plt.plot(t, Recovered, 'g--', label='Recovered')
plt.plot(t, Death, 'r--', label='Dead')
plt.semilogy()
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)
# Out:
# (1, 463650.045941471)

# %%
print('RMSE for infected on last 10 days:', RMSE(Infected[-10:], sol[:, 2][-10:] + sol[:, 3][-10:] + sol[:, 4][-10:]))
print('RMSE for recovered on last 10 days:', RMSE(Recovered[-10:], sol[:, 5][-10:]))
print('RMSE for dead on last 10 days:', RMSE(Death[-10:], sol[:, 6][-10:]))
# Out:
# RMSE for infected on last 10 days: 54549.01520904796
# RMSE for recovered on last 10 days: 16833.052042109404
# RMSE for dead on last 10 days: 10108.696880472302

# %%
print('Train RMSE scores:')
err[np.argmin(ls, axis=0)]
# Out:
# Train RMSE scores:
# (16712.539334557052, 4721.1468037290315, 3691.0325805237094)

# %%
print('best parameters:')
{k:round(v, 4) for k, v in opt_avg.items()}
# Out:
# best parameters:
# {'lambda': 0.0676,
#  'k': 0.015,
#  'gamma': 0.3667,
#  'delta': 0.1889,
#  'beta': 1.0842,
#  'alpha': 0.0256}

# %%
# predicting epidemic end
# I choose best parameters and big t

t = np.arange(600)

sol = odeint(diff_equation, 
             y0, 
             t = t, 
             args=(opt_avg['alpha'], opt_avg['beta'], opt_avg['gamma'], opt_avg['delta'],
                   opt_avg['lambda'], opt_avg['k']))



plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)


plt.subplot(1,2,2)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.semilogy()
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)
# Out:
# (1, 1211638.5105631226)

# %%
x = sol[:, 2] + sol[:, 3] + sol[:, 4]
for i, val in enumerate(x):
    if val <= 1:
        print('Epidemic will end in ~ %s days' %i)
        break
# Out:
# Epidemic will end in ~ 236 days

# %% [markdown]
# # Bad fits: infected, recovered and dead

# %%
sol = odeint(diff_equation, 
             y0, 
             t, 
             args=(opt_i['alpha'], opt_i['beta'], opt_i['gamma'], opt_i['delta'],
                   opt_i['lambda'], opt_i['k']))

plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.plot(t, Infected, 'b', label='Infected')
plt.plot(t, Recovered, 'g', label='Recovered')
plt.plot(t, Death, 'r', label='Dead')
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)


plt.subplot(1,2,2)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.plot(t, Infected, 'b', label='Infected')
plt.plot(t, Recovered, 'g', label='Recovered')
plt.plot(t, Death, 'r', label='Dead')
plt.semilogy()
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)
# Out:
# (1, 465860.70552048413)

# %%
print('RMSE for infected on last 10 days:', RMSE(Infected[-10:], sol[:, 2][-10:] + sol[:, 3][-10:] + sol[:, 4][-10:]))
print('RMSE for recovered on last 10 days:', RMSE(Recovered[-10:], sol[:, 5][-10:]))
print('RMSE for dead on last 10 days:', RMSE(Death[-10:], sol[:, 6][-10:]))
# Out:
# RMSE for infected on last 10 days: 30967.570827476597
# RMSE for recovered on last 10 days: 146202.98853445495
# RMSE for dead on last 10 days: 98098.6760705752

# %%
sol = odeint(diff_equation, 
             y0, 
             t, 
             args=(opt_r['alpha'], opt_r['beta'], opt_r['gamma'], opt_r['delta'],
                   opt_r['lambda'], opt_r['k']))

plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.plot(t, Infected, 'b', label='Infected')
plt.plot(t, Recovered, 'g', label='Recovered')
plt.plot(t, Death, 'r', label='Dead')
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)

plt.subplot(1,2,2)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.plot(t, Infected, 'b', label='Infected')
plt.plot(t, Recovered, 'g', label='Recovered')
plt.plot(t, Death, 'r', label='Dead')
plt.semilogy()
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)
# Out:
# (1, 18218867.061411634)

# %%
print('RMSE for infected on last 10 days:', RMSE(Infected[-10:], sol[:, 2][-10:] + sol[:, 3][-10:] + sol[:, 4][-10:]))
print('RMSE for recovered on last 10 days:', RMSE(Recovered[-10:], sol[:, 5][-10:]))
print('RMSE for dead on last 10 days:', RMSE(Death[-10:], sol[:, 6][-10:]))
# Out:
# RMSE for infected on last 10 days: 767736.0418702569
# RMSE for recovered on last 10 days: 15255.36681988927
# RMSE for dead on last 10 days: 4936746.150321538

# %%
sol = odeint(diff_equation, 
             y0, 
             t, 
             args=(opt_d['alpha'], opt_d['beta'], opt_d['gamma'], opt_d['delta'],
                   opt_d['lambda'], opt_d['k']))

plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.plot(t, Infected, 'b', label='Infected')
plt.plot(t, Recovered, 'g', label='Recovered')
plt.plot(t, Death, 'r', label='Dead')
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)


plt.subplot(1,2,2)
plt.plot(t, sol[:, 2] + sol[:, 3] + sol[:, 4], 'b--',label='Infected Pred')
plt.plot(t, sol[:, 5], 'g--', label='Recovered Pred')
plt.plot(t, sol[:, 6], 'r--', label='Dead Pred')
plt.plot(t, Infected, 'b', label='Infected')
plt.plot(t, Recovered, 'g', label='Recovered')
plt.plot(t, Death, 'r', label='Dead')
plt.semilogy()
plt.xlabel("Time (days)")
plt.ylabel("Number of people")
plt.legend()
plt.ylim(bottom=1)
# Out:
# (1, 6540410.644431487)

# %%
print('RMSE for infected on last 10 days:', RMSE(Infected[-10:], sol[:, 2][-10:] + sol[:, 3][-10:] + sol[:, 4][-10:]))
print('RMSE for recovered on last 10 days:', RMSE(Recovered[-10:], sol[:, 5][-10:]))
print('RMSE for dead on last 10 days:', RMSE(Death[-10:], sol[:, 6][-10:]))
# Out:
# RMSE for infected on last 10 days: 51890.05655687744
# RMSE for recovered on last 10 days: 1815270.7383264631
# RMSE for dead on last 10 days: 781.6381937744451
